# %%
import pandas as pd
import numpy as np

# %%
#We have collected the following Hugo Symbols by Clinical Signal and GWAS 
ensembl_hugo_symbol=['PIK3CA', 'HRAS', 'MEN1', 'PTEN', 'ERBB2', 'TP53', 'RUNX1', 'JAK1', \
           'ERBB3', 'AKT1', 'PIK3R1', 'STK11', 'DNAH5', 'ARID2', 'NF1', 'SMAD4',\
           'CDH1', 'APC', 'TBX3', 'NOTCH1', 'FANCD2', 'RB1', 'BRAF', 'SETD2', 'TG',\
           'COL12A1', 'GLDC', 'SYNE1', 'CHEK2', 'NRAS', 'CDKN2A', 'KRAS', 'BRCA1',\
           'FANCA', 'BRCA2', 'KDM6A', 'RYR2', 'COL6A3', 'USH2A', 'AGMO', 'CDKN1B',\
           'KMT2C', 'LAMA2', 'BAP1', 'MYH9', 'DNAH11', 'ALK', 'AHNAK', 'EP300', 'ARID1B',\
           'MLL2', 'NF2', 'MYO1A', 'ARID1A', 'FOXP1', 'CTCF', 'HERC2', 'NEK1', 'LARGE',\
           'DNAH2', 'MYO3A', 'ATR', 'MAP3K1', 'SF3B1', 'GATA3', 'EGFR', 'BRIP1', 'ERBB4',\
           'ASXL1', 'LAMB3', 'CTNNA3', 'ACVRL1', 'FBXW7']


gwas_hugo_symbol = ['EMBP1', 'Y_RNA', 'U3', 'CASC10', 'MIR1915', 'SKIDA1', 'MLLT10', 'RNU6-306P', 'ZNF365', 'ZMIZ1',\
                    'FGFR2', 'RP11-62L18.3', 'RPS15AP5', 'LSP1', 'MIR4298', 'AC051649.12', 'C11orf89', 'TNNT3', 'AC051649.1',\
                    'AP000439.1', 'AP000439.5', 'AP000439.3', 'GNAI2P1', 'PTHLH', 'RP11-964E11.2', 'PAX9', 'RAD51B', 'CTD-2566J3.1',\
                    'RN7SL706P', 'RN7SL108P', 'SCNN1B', 'PALB2', 'DCTN5', 'ERN2', 'TOX3', 'CASC16', 'RP11-297L17.2', 'RP11-297L17.3',\
                    'RP11-297L17.4', 'FTO', 'MPHOSPH6', 'RP11-510J16.5', 'ATAD5', 'CTD-2349P21.11', 'TEFM', 'CHST9', 'AQP4-AS1',\
                    'SLC14A2', 'CASP8', 'ALS2CR12', 'TRAK2', 'STRADB', 'AC007256.5', 'AC079610.1', 'AC007563.5', 'RP11-574O16.1',\
                    'RN7SKP43', 'LINC00160', 'AP000330.8', 'PITPNB', 'TTC28-AS1', 'MIR3199-2', 'TTC28', 'CHEK2', 'CTA-292E10.6',\
                    'ZNRF3', 'ZNRF3-IT1', 'ZNRF3-AS1', 'C22orf31', 'KREMEN1', 'EMID1', 'THOC5', 'NF2', 'SEC14L4', 'RP4-539M6.14',\
                    'TCN2', 'APOBEC3A', 'ADSL', 'SGSM3', 'MKL1', 'RP5-1042K10.12', 'RP4-591N18.2', 'AL031594.1', 'COX6B1P3',\
                    'RPL4P6', 'NEK10', 'MINOS1P3', 'RNU6-342P', 'AC099535.1', 'SLC4A7', 'RN7SL859P', 'RPS20P15', 'AC099535.4',\
                    'RNU1-96P', 'FAM194A', 'RP11-103G8.2', 'RP11-103G8.1', 'SIAH2', 'SIAH2-AS1', 'ADAM29', 'RP13-577H12.3',\
                    'AC105914.1', 'TERT', 'RP11-473L15.3', 'RP11-503D12.1', 'RN7SL383P', 'RP11-53O19.1', 'RP11-53O19.2', 'MRPS30',\
                    'RP11-53O19.3', 'AC008940.1', 'MAP3K1', 'AC008937.2', 'snoU13', 'AC008937.3', 'SETD9', 'MIER3', 'CTD-2310F14.1',\
                    'AC016644.1', 'AC114973.1', 'EBF1', 'RP1-111D6.2', 'RP1-111D6.3', 'TAB2', 'RN7SL234P', 'CCDC170', 'RNU6-813P',\
                    'ESR1', 'RNU1-58P', 'KCNU1', 'AC090453.1', 'CASC8', 'RP11-382A18.2', 'RP11-438P9.2', 'APOBEC3B-AS1']

# %%
df = pd.read_csv(
   "merged_1_4.csv"
)

df
# Out:
# /var/folders/hn/_7rb9zk51r13c_fprldgz1zc0000gn/T/ipykernel_79920/1947431021.py:1: DtypeWarning: Columns (3,4,7,8,9,11,14,15,16,17,18,19,21,27,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#      PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY  \
# 0       MB-0000                           10.0  6.044         NaN
# 1       MB-0002                            0.0  4.020        High
# 2       MB-0005                            1.0  4.030        High
# 3       MB-0006                            3.0  4.050    Moderate
# 4       MB-0008                            8.0  6.080        High
# ...         ...                            ...    ...         ...
# 2504  MTS-T2428                            0.0  2.540         NaN
# 2505  MTS-T2429                            0.0  4.560         NaN
# 2506  MTS-T2430                            0.0    NaN         NaN
# 2507  MTS-T2431                            0.0    NaN         NaN
# 2508  MTS-T2432                            0.0    NaN         NaN
#
#      CHEMOTHERAPY  COHORT   ER_IHC HER2_SNP6 HORMONE_THERAPY  \
# 0              NO     1.0  Positve   NEUTRAL             YES
# 1              NO     1.0  Positve   NEUTRAL             YES
# 2             YES     1.0  Positve   NEUTRAL             YES
# 3             YES     1.0  Positve   NEUTRAL             YES
# 4             YES     1.0  Positve   NEUTRAL             YES
# ...           ...     ...      ...       ...             ...
# 2504          NaN     1.0  Positve       NaN             NaN
# 2505          NaN     1.0  Positve       NaN             NaN
# 2506          NaN     NaN      NaN       NaN             NaN
# 2507          NaN     NaN      NaN       NaN             NaN
# 2508          NaN     NaN      NaN       NaN             NaN
#
#      INFERRED_MENOPAUSAL_STATE  ... SBF2-AS1_mrna VN1R4_mrna  TRPV5_mrna  \
# 0                         Post  ...      5.295203   5.474224    5.415184
# 1                          Pre  ...      5.442257   5.303871    5.507905
# 2                          Pre  ...      5.368716   5.370394    5.314009
# 3                          Pre  ...      5.295628   5.694697    5.410028
# 4                         Post  ...      5.192858   5.474929    5.389733
# ...                        ...  ...           ...        ...         ...
# 2504                       NaN  ...           NaN        NaN         NaN
# 2505                       NaN  ...           NaN        NaN         NaN
# 2506                       NaN  ...           NaN        NaN         NaN
# 2507                       NaN  ...           NaN        NaN         NaN
# 2508                       NaN  ...           NaN        NaN         NaN
#
#       UGGT1_mrna CR590356_mrna VPS72_mrna CSMD3_mrna CC2D1A_mrna IGSF9_mrna  \
# 0       7.021679      5.947334   8.010657   5.299815    6.235804   5.947404
# 1       7.612797      5.519225   7.988643   5.194247    6.328059   6.938685
# 2       6.619220      5.496590   8.044471   5.306294    6.306927   7.397672
# 3       6.966482      5.600679   7.527300   5.197607    6.515638   6.175716
# 4       6.942461      6.707482   8.115359   5.254136    6.323751   6.272568
# ...          ...           ...        ...        ...         ...        ...
# 2504         NaN           NaN        NaN        NaN         NaN        NaN
# 2505         NaN           NaN        NaN        NaN         NaN        NaN
# 2506         NaN           NaN        NaN        NaN         NaN        NaN
# 2507         NaN           NaN        NaN        NaN         NaN        NaN
# 2508         NaN           NaN        NaN        NaN         NaN        NaN
#
#      FAM71A_mrna
# 0       5.133576
# 1       5.604560
# 2       5.645597
# 3       5.354582
# 4       5.030636
# ...          ...
# 2504         NaN
# 2505         NaN
# 2506         NaN
# 2507         NaN
# 2508         NaN
#
# [2509 rows x 33826 columns]

# %%
#print(df.columns.tolist())

# %%
df["LSP1_mrna.1"].value_counts()
# Out:
# LSP1_mrna.1
# 6.202580    3
# 6.005518    3
# 6.055257    3
# 5.949741    3
# 6.292685    3
#            ..
# 6.116671    1
# 5.672844    1
# 6.879167    1
# 5.748143    1
# 6.577060    1
# Name: count, Length: 1920, dtype: int64

# %%
ensembl_feature_cols = [
    c for c in df.columns
    if "_" in c and c.split("_")[0] in ensembl_hugo_symbol
]

gwas_feature_cols = [
    c for c in df.columns
    if "_" in c and c.split("_")[0] in gwas_hugo_symbol
]




base_cols = [
    'PATIENT_ID', 'LYMPH_NODES_EXAMINED_POSITIVE', 'NPI', 'CELLULARITY', 'CHEMOTHERAPY', 'COHORT',\
                'ER_IHC', 'HER2_SNP6', 'HORMONE_THERAPY', 'INFERRED_MENOPAUSAL_STATE', 'SEX', 'INTCLUST', 'AGE_AT_DIAGNOSIS',\
                'OS_MONTHS', 'OS_STATUS', 'CLAUDIN_SUBTYPE', 'THREEGENE', 'VITAL_STATUS', 'LATERALITY', 'RADIO_THERAPY',\
                'HISTOLOGICAL_SUBTYPE', 'BREAST_SURGERY', 'RFS_MONTHS', 'RFS_STATUS', 'CANCER_TYPE', 'CANCER_TYPE_DETAILED',\
                'ER_STATUS', 'HER2_STATUS', 'GRADE', 'ONCOTREE_CODE', 'PR_STATUS', 'SAMPLE_TYPE', 'TUMOR_SIZE', 'TUMOR_STAGE',\
                'TMB_NONSYNONYMOUS'
]

cols_to_keep = list(dict.fromkeys(
    base_cols + ensembl_feature_cols + gwas_feature_cols
))



df_filtered = df[cols_to_keep]

# %%
cols_to_keep
# Out:
# ['PATIENT_ID',
#  'LYMPH_NODES_EXAMINED_POSITIVE',
#  'NPI',
#  'CELLULARITY',
#  'CHEMOTHERAPY',
#  'COHORT',
#  'ER_IHC',
#  'HER2_SNP6',
#  'HORMONE_THERAPY',
#  'INFERRED_MENOPAUSAL_STATE',
#  'SEX',
#  'INTCLUST',
#  'AGE_AT_DIAGNOSIS',
#  'OS_MONTHS',
#  'OS_STATUS',
#  'CLAUDIN_SUBTYPE',
#  'THREEGENE',
#  'VITAL_STATUS',
#  'LATERALITY',
#  'RADIO_THERAPY',
#  'HISTOLOGICAL_SUBTYPE',
#  'BREAST_SURGERY',
#  'RFS_MONTHS',
#  'RFS_STATUS',
#  'CANCER_TYPE',
#  'CANCER_TYPE_DETAILED',
#  'ER_STATUS',
#  'HER2_STATUS',
#  'GRADE',
#  'ONCOTREE_CODE',
#  'PR_STATUS',
#  'SAMPLE_TYPE',
#  'TUMOR_SIZE',
#  'TUMOR_STAGE',
#  'TMB_NONSYNONYMOUS',
#  'ACVRL1_methy',
#  'AHNAK_methy',
#  'AKT1_methy',
#  'ALK_methy',
#  'APC_methy',
#  'ARID1A_methy',
#  'ARID1B_methy',
#  'ARID2_methy',
#  'ASXL1_methy',
#  'ATR_methy',
#  'BAP1_methy',
#  'BRAF_methy',
#  'BRCA1_methy',
#  'BRCA2_methy',
#  'BRIP1_methy',
#  'CDH1_methy',
#  'CDKN1B_methy',
#  'CDKN2A_methy',
#  'CHEK2_methy',
#  'COL12A1_methy',
#  'CTCF_methy',
#  'DNAH11_methy',
#  'DNAH2_methy',
#  'EGFR_methy',
#  'EP300_methy',
#  'ERBB2_methy',
#  'ERBB3_methy',
#  'ERBB4_methy',
#  'FANCA_methy',
#  'FANCD2_methy',
#  'FBXW7_methy',
#  'FOXP1_methy',
#  'GATA3_methy',
#  'GLDC_methy',
#  'HRAS_methy',
#  'JAK1_methy',
#  'KDM6A_methy',
#  'KMT2C_methy',
#  'KRAS_methy',
#  'LAMA2_methy',
#  'LAMB3_methy',
#  'LARGE_methy',
#  'MEN1_methy',
#  'MYO3A_methy',
#  'NF1_methy',
#  'NF2_methy',
#  'NOTCH1_methy',
#  'PIK3CA_methy',
#  'PIK3R1_methy',
#  'PTEN_methy',
#  'RB1_methy',
#  'RUNX1_methy',
#  'RYR2_methy',
#  'SETD2_methy',
#  'SMAD4_methy',
#  'STK11_methy',
#  'SYNE1_methy',
#  'TBX3_methy',
#  'TP53_methy',
#  'AGMO_mrna',
#  'AHNAK_mrna',
#  'ALK_mrna',
#  'LAMB3_mrna',
#  'SMAD4_mrna',
#  'CDKN1B_mrna',
#  'EGFR_mrna',
#  'NF2_mrna',
#  'SETD2_mrna',
#  'CDH1_mrna',
#  'LAMA2_mrna',
#  'PIK3R1_mrna',
#  'MYH9_mrna',
#  'BRCA2_mrna',
#  'RYR2_mrna',
#  'JAK1_mrna',
#  'HRAS_mrna',
#  'FBXW7_mrna',
#  'FANCA_mrna',
#  'KMT2C_mrna',
#  'USH2A_mrna',
#  'DNAH5_mrna',
#  'KRAS_mrna',
#  'COL6A3_mrna',
#  'ARID1B_mrna',
#  'MYO3A_mrna',
#  'FANCD2_mrna',
#  'KDM6A_mrna',
#  'FOXP1_mrna',
#  'BRCA1_mrna',
#  'COL12A1_mrna',
#  'ARID1B_mrna.1',
#  'BAP1_mrna',
#  'ATR_mrna',
#  'ERBB2_mrna',
#  'STK11_mrna',
#  'TP53_mrna',
#  'GLDC_mrna',
#  'ERBB4_mrna',
#  'MAP3K1_mrna',
#  'ERBB3_mrna',
#  'ACVRL1_mrna',
#  'TG_mrna',
#  'PTEN_mrna',
#  'NEK1_mrna',
#  'SETD2_mrna.1',
#  'PIK3CA_mrna',
#  'NOTCH1_mrna',
#  'CTCF_mrna',
#  'SF3B1_mrna',
#  'ASXL1_mrna',
#  'SYNE1_mrna',
#  'APC_mrna',
#  'GATA3_mrna',
#  'BRIP1_mrna',
#  'NRAS_mrna',
#  'ARID1B_mrna.2',
#  'HERC2_mrna',
#  'AKT1_mrna',
#  'ARID1A_mrna',
#  'RB1_mrna',
#  'MYO1A_mrna',
#  'CDKN2A_mrna',
#  'MEN1_mrna',
#  'DNAH2_mrna',
#  'NF1_mrna',
#  'CTNNA3_mrna',
#  'ARID2_mrna',
#  'TBX3_mrna',
#  'BRAF_mrna',
#  'DNAH11_mrna',
#  'CHEK2_mrna',
#  'RUNX1_mrna',
#  'EP300_mrna',
#  'ADSL_methy',
#  'ATAD5_methy',
#  'CCDC170_methy',
#  'DCTN5_methy',
#  'EMBP1_methy',
#  'EMID1_methy',
#  'ERN2_methy',
#  'ESR1_methy',
#  'FGFR2_methy',
#  'LSP1_methy',
#  'MIER3_methy',
#  'MIR1915_methy',
#  'MKL1_methy',
#  'MLLT10_methy',
#  'MPHOSPH6_methy',
#  'NEK10_methy',
#  'PALB2_methy',
#  'PAX9_methy',
#  'PITPNB_methy',
#  'PTHLH_methy',
#  'RAD51B_methy',
#  'SCNN1B_methy',
#  'SEC14L4_methy',
#  'SETD9_methy',
#  'SIAH2_methy',
#  'SKIDA1_methy',
#  'SLC4A7_methy',
#  'STRADB_methy',
#  'TAB2_methy',
#  'TCN2_methy',
#  'TEFM_methy',
#  'TERT_methy',
#  'TNNT3_methy',
#  'TOX3_methy',
#  'TRAK2_methy',
#  'TTC28_methy',
#  'ZMIZ1_methy',
#  'ZNF365_methy',
#  'ZNRF3_methy',
#  'SLC14A2_mrna',
#  'NEK10_mrna',
#  'SGSM3_mrna',
#  'CASC16_mrna',
#  'SLC4A7_mrna',
#  'LSP1_mrna',
#  'EBF1_mrna',
#  'ZNRF3_mrna',
#  'ERN2_mrna',
#  'SCNN1B_mrna',
#  'ADAM29_mrna',
#  'PITPNB_mrna',
#  'SIAH2_mrna',
#  'AQP4-AS1_mrna',
#  'MPHOSPH6_mrna',
#  'ZMIZ1_mrna',
#  'LINC00160_mrna',
#  'TAB2_mrna',
#  'CASP8_mrna',
#  'FTO_mrna',
#  'STRADB_mrna',
#  'FGFR2_mrna',
#  'THOC5_mrna',
#  'RAD51B_mrna',
#  'TRAK2_mrna',
#  'ESR1_mrna',
#  'KREMEN1_mrna',
#  'TOX3_mrna',
#  'C22orf31_mrna',
#  'PALB2_mrna',
#  'TNNT3_mrna',
#  'LSP1_mrna.1',
#  'ZNF365_mrna',
#  'CCDC170_mrna',
#  'CHST9_mrna',
#  'DCTN5_mrna',
#  'TCN2_mrna',
#  'ADSL_mrna',
#  'TERT_mrna',
#  'MIER3_mrna',
#  'SETD9_mrna',
#  'EMID1_mrna',
#  'TTC28_mrna',
#  'ATAD5_mrna',
#  'PAX9_mrna',
#  'MLLT10_mrna',
#  'PTHLH_mrna',
#  'SKIDA1_mrna',
#  'MRPS30_mrna',
#  'APOBEC3A_mrna',
#  'SEC14L4_mrna']

# %%
print(df_filtered.columns.tolist())
# Out:
# ['PATIENT_ID', 'LYMPH_NODES_EXAMINED_POSITIVE', 'NPI', 'CELLULARITY', 'CHEMOTHERAPY', 'COHORT', 'ER_IHC', 'HER2_SNP6', 'HORMONE_THERAPY', 'INFERRED_MENOPAUSAL_STATE', 'SEX', 'INTCLUST', 'AGE_AT_DIAGNOSIS', 'OS_MONTHS', 'OS_STATUS', 'CLAUDIN_SUBTYPE', 'THREEGENE', 'VITAL_STATUS', 'LATERALITY', 'RADIO_THERAPY', 'HISTOLOGICAL_SUBTYPE', 'BREAST_SURGERY', 'RFS_MONTHS', 'RFS_STATUS', 'CANCER_TYPE', 'CANCER_TYPE_DETAILED', 'ER_STATUS', 'HER2_STATUS', 'GRADE', 'ONCOTREE_CODE', 'PR_STATUS', 'SAMPLE_TYPE', 'TUMOR_SIZE', 'TUMOR_STAGE', 'TMB_NONSYNONYMOUS', 'ACVRL1_methy', 'AHNAK_methy', 'AKT1_methy', 'ALK_methy', 'APC_methy', 'ARID1A_methy', 'ARID1B_methy', 'ARID2_methy', 'ASXL1_methy', 'ATR_methy', 'BAP1_methy', 'BRAF_methy', 'BRCA1_methy', 'BRCA2_methy', 'BRIP1_methy', 'CDH1_methy', 'CDKN1B_methy', 'CDKN2A_methy', 'CHEK2_methy', 'COL12A1_methy', 'CTCF_methy', 'DNAH11_methy', 'DNAH2_methy', 'EGFR_methy', 'EP300_methy', 'ERBB2_methy', 'ERBB3_methy', 'ERBB4_methy', 'FANCA_methy', 'FANCD2_methy', 'FBXW7_methy', 'FOXP1_methy', 'GATA3_methy', 'GLDC_methy', 'HRAS_methy', 'JAK1_methy', 'KDM6A_methy', 'KMT2C_methy', 'KRAS_methy', 'LAMA2_methy', 'LAMB3_methy', 'LARGE_methy', 'MEN1_methy', 'MYO3A_methy', 'NF1_methy', 'NF2_methy', 'NOTCH1_methy', 'PIK3CA_methy', 'PIK3R1_methy', 'PTEN_methy', 'RB1_methy', 'RUNX1_methy', 'RYR2_methy', 'SETD2_methy', 'SMAD4_methy', 'STK11_methy', 'SYNE1_methy', 'TBX3_methy', 'TP53_methy', 'AGMO_mrna', 'AHNAK_mrna', 'ALK_mrna', 'LAMB3_mrna', 'SMAD4_mrna', 'CDKN1B_mrna', 'EGFR_mrna', 'NF2_mrna', 'SETD2_mrna', 'CDH1_mrna', 'LAMA2_mrna', 'PIK3R1_mrna', 'MYH9_mrna', 'BRCA2_mrna', 'RYR2_mrna', 'JAK1_mrna', 'HRAS_mrna', 'FBXW7_mrna', 'FANCA_mrna', 'KMT2C_mrna', 'USH2A_mrna', 'DNAH5_mrna', 'KRAS_mrna', 'COL6A3_mrna', 'ARID1B_mrna', 'MYO3A_mrna', 'FANCD2_mrna', 'KDM6A_mrna', 'FOXP1_mrna', 'BRCA1_mrna', 'COL12A1_mrna', 'ARID1B_mrna.1', 'BAP1_mrna', 'ATR_mrna', 'ERBB2_mrna', 'STK11_mrna', 'TP53_mrna', 'GLDC_mrna', 'ERBB4_mrna', 'MAP3K1_mrna', 'ERBB3_mrna', 'ACVRL1_mrna', 'TG_mrna', 'PTEN_mrna', 'NEK1_mrna', 'SETD2_mrna.1', 'PIK3CA_mrna', 'NOTCH1_mrna', 'CTCF_mrna', 'SF3B1_mrna', 'ASXL1_mrna', 'SYNE1_mrna', 'APC_mrna', 'GATA3_mrna', 'BRIP1_mrna', 'NRAS_mrna', 'ARID1B_mrna.2', 'HERC2_mrna', 'AKT1_mrna', 'ARID1A_mrna', 'RB1_mrna', 'MYO1A_mrna', 'CDKN2A_mrna', 'MEN1_mrna', 'DNAH2_mrna', 'NF1_mrna', 'CTNNA3_mrna', 'ARID2_mrna', 'TBX3_mrna', 'BRAF_mrna', 'DNAH11_mrna', 'CHEK2_mrna', 'RUNX1_mrna', 'EP300_mrna', 'ADSL_methy', 'ATAD5_methy', 'CCDC170_methy', 'DCTN5_methy', 'EMBP1_methy', 'EMID1_methy', 'ERN2_methy', 'ESR1_methy', 'FGFR2_methy', 'LSP1_methy', 'MIER3_methy', 'MIR1915_methy', 'MKL1_methy', 'MLLT10_methy', 'MPHOSPH6_methy', 'NEK10_methy', 'PALB2_methy', 'PAX9_methy', 'PITPNB_methy', 'PTHLH_methy', 'RAD51B_methy', 'SCNN1B_methy', 'SEC14L4_methy', 'SETD9_methy', 'SIAH2_methy', 'SKIDA1_methy', 'SLC4A7_methy', 'STRADB_methy', 'TAB2_methy', 'TCN2_methy', 'TEFM_methy', 'TERT_methy', 'TNNT3_methy', 'TOX3_methy', 'TRAK2_methy', 'TTC28_methy', 'ZMIZ1_methy', 'ZNF365_methy', 'ZNRF3_methy', 'SLC14A2_mrna', 'NEK10_mrna', 'SGSM3_mrna', 'CASC16_mrna', 'SLC4A7_mrna', 'LSP1_mrna', 'EBF1_mrna', 'ZNRF3_mrna', 'ERN2_mrna', 'SCNN1B_mrna', 'ADAM29_mrna', 'PITPNB_mrna', 'SIAH2_mrna', 'AQP4-AS1_mrna', 'MPHOSPH6_mrna', 'ZMIZ1_mrna', 'LINC00160_mrna', 'TAB2_mrna', 'CASP8_mrna', 'FTO_mrna', 'STRADB_mrna', 'FGFR2_mrna', 'THOC5_mrna', 'RAD51B_mrna', 'TRAK2_mrna', 'ESR1_mrna', 'KREMEN1_mrna', 'TOX3_mrna', 'C22orf31_mrna', 'PALB2_mrna', 'TNNT3_mrna', 'LSP1_mrna.1', 'ZNF365_mrna', 'CCDC170_mrna', 'CHST9_mrna', 'DCTN5_mrna', 'TCN2_mrna', 'ADSL_mrna', 'TERT_mrna', 'MIER3_mrna', 'SETD9_mrna', 'EMID1_mrna', 'TTC28_mrna', 'ATAD5_mrna', 'PAX9_mrna', 'MLLT10_mrna', 'PTHLH_mrna', 'SKIDA1_mrna', 'MRPS30_mrna', 'APOBEC3A_mrna', 'SEC14L4_mrna']

# %%
df_filtered
# Out:
#      PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY  \
# 0       MB-0000                           10.0  6.044         NaN
# 1       MB-0002                            0.0  4.020        High
# 2       MB-0005                            1.0  4.030        High
# 3       MB-0006                            3.0  4.050    Moderate
# 4       MB-0008                            8.0  6.080        High
# ...         ...                            ...    ...         ...
# 2504  MTS-T2428                            0.0  2.540         NaN
# 2505  MTS-T2429                            0.0  4.560         NaN
# 2506  MTS-T2430                            0.0    NaN         NaN
# 2507  MTS-T2431                            0.0    NaN         NaN
# 2508  MTS-T2432                            0.0    NaN         NaN
#
#      CHEMOTHERAPY  COHORT   ER_IHC HER2_SNP6 HORMONE_THERAPY  \
# 0              NO     1.0  Positve   NEUTRAL             YES
# 1              NO     1.0  Positve   NEUTRAL             YES
# 2             YES     1.0  Positve   NEUTRAL             YES
# 3             YES     1.0  Positve   NEUTRAL             YES
# 4             YES     1.0  Positve   NEUTRAL             YES
# ...           ...     ...      ...       ...             ...
# 2504          NaN     1.0  Positve       NaN             NaN
# 2505          NaN     1.0  Positve       NaN             NaN
# 2506          NaN     NaN      NaN       NaN             NaN
# 2507          NaN     NaN      NaN       NaN             NaN
# 2508          NaN     NaN      NaN       NaN             NaN
#
#      INFERRED_MENOPAUSAL_STATE  ... EMID1_mrna TTC28_mrna  ATAD5_mrna  \
# 0                         Post  ...   5.825269   5.798647    5.762455
# 1                          Pre  ...   5.698300   5.609069    5.807519
# 2                          Pre  ...   5.713216   5.485918    5.704256
# 3                          Pre  ...   5.501439   5.356186    5.670296
# 4                         Post  ...   6.018440   5.738390    5.705560
# ...                        ...  ...        ...        ...         ...
# 2504                       NaN  ...        NaN        NaN         NaN
# 2505                       NaN  ...        NaN        NaN         NaN
# 2506                       NaN  ...        NaN        NaN         NaN
# 2507                       NaN  ...        NaN        NaN         NaN
# 2508                       NaN  ...        NaN        NaN         NaN
#
#       PAX9_mrna MLLT10_mrna PTHLH_mrna SKIDA1_mrna MRPS30_mrna APOBEC3A_mrna  \
# 0      5.469058    7.263043   6.013555    5.608817    8.535214      5.336678
# 1      6.411290    8.121593   5.764321    6.050104    9.628202      5.377759
# 2      5.817795    6.877284   9.808890    5.321103    8.915721      5.338215
# 3      6.377648    7.235799   6.089555    5.639904    9.058717      5.515105
# 4      5.596711    7.947678   6.121529    5.328361    9.860345      5.375316
# ...         ...         ...        ...         ...         ...           ...
# 2504        NaN         NaN        NaN         NaN         NaN           NaN
# 2505        NaN         NaN        NaN         NaN         NaN           NaN
# 2506        NaN         NaN        NaN         NaN         NaN           NaN
# 2507        NaN         NaN        NaN         NaN         NaN           NaN
# 2508        NaN         NaN        NaN         NaN         NaN           NaN
#
#      SEC14L4_mrna
# 0        5.868042
# 1        5.747465
# 2        5.554798
# 3        5.881517
# 4        5.278561
# ...           ...
# 2504          NaN
# 2505          NaN
# 2506          NaN
# 2507          NaN
# 2508          NaN
#
# [2509 rows x 258 columns]

# %% [raw]
# df_filtered.to_csv(
#     "genomics_selected_gwas_ensembl_new.csv"
# )
